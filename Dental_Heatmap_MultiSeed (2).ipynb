# %% [markdown]
# # Dental Caries Staging — Multi-Seed Robustness Follow-Up
#
# This notebook extends `Dental_Heatmap_Fixed.ipynb` to address its main stated limitation:
# results were previously based on a **single train/val/test split and a single training run
# per model**, so small accuracy differences between models (all within ~1.5 points) couldn't
# be distinguished from run-to-run noise.
#
# **What this notebook adds:**
# 1. **N repeated runs per model**, each with a different random seed that controls the
#    data split *and* model initialization/training stochasticity together (so both sources
#    of variance are captured, not just weight init).
# 2. **Mean ± standard deviation** for accuracy, macro precision/recall/F1, and macro AUROC
#    per model, instead of a single point estimate.
# 3. **Paired statistical significance testing** (paired t-test across seeds) between every
#    pair of models, so "ResNet-50 vs. ViT-B/16" or "DenseNet-121 vs. SqueezeNet 1.1" can be
#    backed by a p-value rather than eyeballed from a table.
# 4. The qualitative **Grad-CAM / attention-rollout explainability figures** are kept, generated
#    once from the primary seed (the first entry in `SEEDS`) to avoid needing N complete sets
#    of explainability figures.
#
# **Runtime note:** with the default `SEEDS = [42, 123, 2024, 7, 1000]` (5 seeds), this trains
# 4 models × 5 seeds = 20 full 15-epoch runs. On a Colab T4 GPU this can take roughly 2–3 hours
# total. If you're time-constrained, trim `SEEDS` to 3 values (e.g. `[42, 123, 2024]`) —
# everything below works unchanged with any number of seeds ≥ 2.

# %%
# 1. Unzip dataset
import zipfile
import os

zip_file_path = '/content/Caries_Dataset.zip'
extract_dir = '/content/Caries_Dataset_extracted/'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"'{zip_file_path}' unzipped to '{extract_dir}' successfully.")
# Out:
# '/content/Caries_Dataset.zip' unzipped to '/content/Caries_Dataset_extracted/' successfully.

# %%
# 2. Global configuration
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split, Dataset
from torchvision import datasets, transforms, models
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using execution device: {device}")

DATA_DIR = '/content/Caries_Dataset_extracted'
CLASS_NAMES = ['AdvanceEnamel_Caries', 'EarlyStageEnamel_Caries', 'NoEnamel_Caries']
MODEL_LIST = ['ResNet-50', 'DenseNet-121', 'ViT-B/16', 'SqueezeNet 1.1']

# Each seed controls BOTH the data split and model init/training stochasticity for that run,
# so repeated-seed variance reflects total run-to-run variability, not just weight init.
SEEDS = [42, 123, 2024, 7, 1000]
PRIMARY_SEED = SEEDS[0]  # used for the qualitative Grad-CAM / attention-rollout figures

full_dataset = datasets.ImageFolder(root=DATA_DIR)
print(f"Class-to-index mapping: {full_dataset.class_to_idx}")
print(f"Total images: {len(full_dataset)}")
# Out:
# Using execution device: cuda:0
# Class-to-index mapping: {'AdvanceEnamel_Caries': 0, 'EarlyStageEnamel_Caries': 1, 'NoEnamel_Caries': 2}
# Total images: 2234

# %%
# 3. Reusable split / loader / class-weight construction, parameterized by seed

class TransformedDataset(Dataset):
    # Wraps a Subset of the untransformed ImageFolder with a model-specific transform.
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y

    def __len__(self):
        return len(self.subset)


def make_split(seed):
    n_total = len(full_dataset)
    n_train = int(0.70 * n_total)
    n_val = int(0.15 * n_total)
    n_test = n_total - n_train - n_val
    generator = torch.Generator().manual_seed(seed)
    return random_split(full_dataset, [n_train, n_val, n_test], generator=generator)


def make_class_weights(train_subset):
    train_targets = [full_dataset.targets[i] for i in train_subset.indices]
    counts = np.bincount(train_targets, minlength=len(CLASS_NAMES))
    total = sum(counts)
    weights = torch.FloatTensor([total / c for c in counts]).to(device)
    return weights, counts


def make_loaders(resolution, train_subset, val_subset, test_subset, batch_size=16, num_workers=2):
    train_transform = transforms.Compose([
        transforms.Resize((resolution, resolution)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    eval_transform = transforms.Compose([
        transforms.Resize((resolution, resolution)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    train_loader = DataLoader(TransformedDataset(train_subset, train_transform),
                               batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader = DataLoader(TransformedDataset(val_subset, eval_transform),
                             batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader = DataLoader(TransformedDataset(test_subset, eval_transform),
                              batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return train_loader, val_loader, test_loader


RESOLUTION_BY_MODEL = {
    'ResNet-50': 384,
    'DenseNet-121': 384,
    'ViT-B/16': 224,
    'SqueezeNet 1.1': 224,
}

# %%
# 4. Model factory -- encapsulates each architecture's fine-tuning recipe (matching the
# single-run notebook's final, corrected hyperparameters) so it can be rebuilt fresh per seed.

def build_model_and_optimizer(model_name, device):
    if model_name == 'ResNet-50':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        for name, child in model.named_children():
            requires_grad = name in ['layer4', 'fc']
            for param in child.parameters():
                param.requires_grad = requires_grad
        model.fc = nn.Linear(model.fc.in_features, 3)
        model = model.to(device)
        optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

    elif model_name == 'DenseNet-121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
        for name, param in model.named_parameters():
            param.requires_grad = (name.startswith('features.denseblock4')
                                    or name.startswith('features.norm5')
                                    or name.startswith('classifier'))
        model.classifier = nn.Linear(model.classifier.in_features, 3)
        model = model.to(device)
        optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

    elif model_name == 'ViT-B/16':
        model = models.vit_b_16(weights=models.ViT_B_16_Weights.DEFAULT)
        for name, param in model.named_parameters():
            param.requires_grad = (name.startswith('encoder.layers.encoder_layer_11')
                                    or name.startswith('encoder.ln')
                                    or name.startswith('heads'))
        model.heads.head = nn.Linear(model.heads.head.in_features, 3)
        model = model.to(device)
        optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=5e-5, weight_decay=0.01)

    elif model_name == 'SqueezeNet 1.1':
        model = models.squeezenet1_1(weights=models.SqueezeNet1_1_Weights.DEFAULT)
        for param in model.parameters():
            param.requires_grad = True  # fully fine-tuned (see notebook 2's finding that
                                         # a frozen-backbone variant underperformed)
        model.classifier[1] = nn.Conv2d(512, 3, kernel_size=(1, 1), stride=(1, 1))
        model.num_classes = 3
        model = model.to(device)
        optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

    else:
        raise ValueError(f"Unknown model_name: {model_name}")

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)
    return model, optimizer, scheduler


def count_parameters(model):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable

# %%
# 5. Training / evaluation loop (unchanged logic from the single-run notebook)

def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, run_label):
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
    for epoch in range(num_epochs):
        for phase in ['train', 'val']:
            model.train() if phase == 'train' else model.eval()
            dataloader = train_loader if phase == 'train' else val_loader

            running_loss, running_corrects, n_seen = 0.0, 0, 0
            for inputs, labels in dataloader:
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                n_seen += inputs.size(0)

            epoch_loss = running_loss / n_seen
            epoch_acc = (running_corrects.double() / n_seen).item()
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc)
            if phase == 'val':
                scheduler.step(epoch_loss)

        print(f"[{run_label}] Epoch {epoch + 1}/{num_epochs} | "
              f"train_loss={history['train_loss'][-1]:.4f} val_loss={history['val_loss'][-1]:.4f} "
              f"val_acc={history['val_acc'][-1]:.4f}")
    return history


def evaluate_model(model, dataloader, class_names, run_label=""):
    model.eval()
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(labels.numpy())

    report_dict = classification_report(all_labels, all_preds, target_names=class_names, output_dict=True, zero_division=0)
    all_labels_one_hot = np.eye(len(class_names))[all_labels]
    try:
        macro_auroc = roc_auc_score(all_labels_one_hot, all_probs, multi_class='ovr', average='macro')
    except ValueError:
        macro_auroc = np.nan

    print(f"[{run_label}] Test accuracy={report_dict['accuracy']:.4f} "
          f"macro_F1={report_dict['macro avg']['f1-score']:.4f} macro_AUROC={macro_auroc:.4f}")

    return {
        'accuracy': report_dict['accuracy'],
        'precision_macro': report_dict['macro avg']['precision'],
        'recall_macro': report_dict['macro avg']['recall'],
        'f1_macro': report_dict['macro avg']['f1-score'],
        'auroc_macro': macro_auroc,
    }

# %%
# 6. MAIN MULTI-SEED LOOP
# Trains all 4 models for each seed in SEEDS. Models/loaders from the PRIMARY_SEED run are
# kept in `primary_models` / `primary_test_loaders` for the explainability figures below.

all_results = []          # one row per (seed, model)
primary_models = {}       # model_name -> trained model object, from PRIMARY_SEED only
primary_test_loaders = {} # model_name -> test_loader, from PRIMARY_SEED only
primary_histories = {}    # model_name -> training history, from PRIMARY_SEED only

for seed in SEEDS:
    print(f"\n{'=' * 70}\nSEED {seed}\n{'=' * 70}")
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    train_subset, val_subset, test_subset = make_split(seed)
    class_weights_tensor, train_counts = make_class_weights(train_subset)
    print(f"Split sizes -> train={len(train_subset)} val={len(val_subset)} test={len(test_subset)} "
          f"| train class counts={train_counts}")

    for model_name in MODEL_LIST:
        run_label = f"{model_name} | seed {seed}"
        resolution = RESOLUTION_BY_MODEL[model_name]
        train_loader, val_loader, test_loader = make_loaders(resolution, train_subset, val_subset, test_subset)

        model, optimizer, scheduler = build_model_and_optimizer(model_name, device)
        criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

        history = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler,
                               num_epochs=15, run_label=run_label)
        metrics = evaluate_model(model, test_loader, CLASS_NAMES, run_label=run_label)
        total_params, trainable_params = count_parameters(model)

        all_results.append({
            'seed': seed,
            'model': model_name,
            **metrics,
            'total_params': total_params,
            'trainable_params': trainable_params,
        })

        if seed == PRIMARY_SEED:
            primary_models[model_name] = model
            primary_test_loaders[model_name] = test_loader
            primary_histories[model_name] = history

print("\nAll seeds complete.")
# Out:
# ======================================================================
# SEED 42
# ======================================================================
# Split sizes -> train=1563 val=335 test=336 | train class counts=[570 558 435]
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 151MB/s]
# [ResNet-50 | seed 42] Epoch 1/15 | train_loss=0.7040 val_loss=0.3652 val_acc=0.8806
# [ResNet-50 | seed 42] Epoch 2/15 | train_loss=0.2982 val_loss=0.2177 val_acc=0.9194
# [ResNet-50 | seed 42] Epoch 3/15 | train_loss=0.1809 val_loss=0.1620 val_acc=0.9284
# [ResNet-50 | seed 42] Epoch 4/15 | train_loss=0.1457 val_loss=0.1532 val_acc=0.9313
# [ResNet-50 | seed 42] Epoch 5/15 | train_loss=0.1357 val_loss=0.1115 val_acc=0.9582
# [ResNet-50 | seed 42] Epoch 6/15 | train_loss=0.1167 val_loss=0.0822 val_acc=0.9642
# [ResNet-50 | seed 42] Epoch 7/15 | train_loss=0.0979 val_loss=0.0936 val_acc=0.9701
# [ResNet-50 | seed 42] Epoch 8/15 | train_loss=0.0730 val_loss=0.1079 val_acc=0.9642
# [ResNet-50 | seed 42] Epoch 9/15 | train_loss=0.0885 val_loss=0.1056 val_acc=0.9642
# [ResNet-50 | seed 42] Epoch 10/15 | train_loss=0.0671 val_loss=0.0770 val_acc=0.9731
# [ResNet-50 | seed 42] Epoch 11/15 | train_loss=0.0560 val_loss=0.0739 val_acc=0.9731
# [ResNet-50 | seed 42] Epoch 12/15 | train_loss=0.0576 val_loss=0.0630 val_acc=0.9821
# [ResNet-50 | seed 42] Epoch 13/15 | train_loss=0.0387 val_loss=0.0565 val_acc=0.9851
# [ResNet-50 | seed 42] Epoch 14/15 | train_loss=0.0478 val_loss=0.0581 val_acc=0.9761
# [ResNet-50 | seed 42] Epoch 15/15 | train_loss=0.0416 val_loss=0.0721 val_acc=0.9791
# [ResNet-50 | seed 42] Test accuracy=0.9881 macro_F1=0.9882 macro_AUROC=0.9982
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 180MB/s]
# [DenseNet-121 | seed 42] Epoch 1/15 | train_loss=0.7111 val_loss=0.5258 val_acc=0.8209
# [DenseNet-121 | seed 42] Epoch 2/15 | train_loss=0.3988 val_loss=0.3289 val_acc=0.8657
# [DenseNet-121 | seed 42] Epoch 3/15 | train_loss=0.2882 val_loss=0.2951 val_acc=0.8866
# [DenseNet-121 | seed 42] Epoch 4/15 | train_loss=0.2485 val_loss=0.2197 val_acc=0.9104
# [DenseNet-121 | seed 42] Epoch 5/15 | train_loss=0.2110 val_loss=0.2349 val_acc=0.8955
# [DenseNet-121 | seed 42] Epoch 6/15 | train_loss=0.1867 val_loss=0.1662 val_acc=0.9254
# [DenseNet-121 | seed 42] Epoch 7/15 | train_loss=0.1742 val_loss=0.1445 val_acc=0.9343
# [DenseNet-121 | seed 42] Epoch 8/15 | train_loss=0.1308 val_loss=0.1104 val_acc=0.9582
# [DenseNet-121 | seed 42] Epoch 9/15 | train_loss=0.1313 val_loss=0.1236 val_acc=0.9493
# [DenseNet-121 | seed 42] Epoch 10/15 | train_loss=0.1146 val_loss=0.1122 val_acc=0.9612
# [DenseNet-121 | seed 42] Epoch 11/15 | train_loss=0.1140 val_loss=0.0954 val_acc=0.9582
# [DenseNet-121 | seed 42] Epoch 12/15 | train_loss=0.1136 val_loss=0.1360 val_acc=0.9373
# [DenseNet-121 | seed 42] Epoch 13/15 | train_loss=0.0966 val_loss=0.0878 val_acc=0.9522
# [DenseNet-121 | seed 42] Epoch 14/15 | train_loss=0.0787 val_loss=0.0942 val_acc=0.9731
# [DenseNet-121 | seed 42] Epoch 15/15 | train_loss=0.1023 val_loss=0.0816 val_acc=0.9642
# [DenseNet-121 | seed 42] Test accuracy=0.9792 macro_F1=0.9795 macro_AUROC=0.9995
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:04<00:00, 72.3MB/s]
# [ViT-B/16 | seed 42] Epoch 1/15 | train_loss=0.6652 val_loss=0.4162 val_acc=0.8060
# [ViT-B/16 | seed 42] Epoch 2/15 | train_loss=0.3042 val_loss=0.2967 val_acc=0.8716
# [ViT-B/16 | seed 42] Epoch 3/15 | train_loss=0.2059 val_loss=0.2154 val_acc=0.9104
# [ViT-B/16 | seed 42] Epoch 4/15 | train_loss=0.1549 val_loss=0.1786 val_acc=0.9194
# [ViT-B/16 | seed 42] Epoch 5/15 | train_loss=0.1257 val_loss=0.1691 val_acc=0.9284
# [ViT-B/16 | seed 42] Epoch 6/15 | train_loss=0.1201 val_loss=0.1330 val_acc=0.9343
# [ViT-B/16 | seed 42] Epoch 7/15 | train_loss=0.1126 val_loss=0.1538 val_acc=0.9343
# [ViT-B/16 | seed 42] Epoch 8/15 | train_loss=0.0853 val_loss=0.1244 val_acc=0.9373
# [ViT-B/16 | seed 42] Epoch 9/15 | train_loss=0.0821 val_loss=0.1456 val_acc=0.9463
# [ViT-B/16 | seed 42] Epoch 10/15 | train_loss=0.0675 val_loss=0.1080 val_acc=0.9433
# [ViT-B/16 | seed 42] Epoch 11/15 | train_loss=0.0556 val_loss=0.1278 val_acc=0.9552
# [ViT-B/16 | seed 42] Epoch 12/15 | train_loss=0.0686 val_loss=0.1018 val_acc=0.9522
# [ViT-B/16 | seed 42] Epoch 13/15 | train_loss=0.0600 val_loss=0.1057 val_acc=0.9493
# [ViT-B/16 | seed 42] Epoch 14/15 | train_loss=0.0523 val_loss=0.0982 val_acc=0.9582
# [ViT-B/16 | seed 42] Epoch 15/15 | train_loss=0.0439 val_loss=0.0927 val_acc=0.9552
# [ViT-B/16 | seed 42] Test accuracy=0.9851 macro_F1=0.9853 macro_AUROC=0.9984
# Downloading: "https://download.pytorch.org/models/squeezenet1_1-b8a52dc0.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_1-b8a52dc0.pth
# 100%|██████████| 4.73M/4.73M [00:00<00:00, 121MB/s]
# [SqueezeNet 1.1 | seed 42] Epoch 1/15 | train_loss=0.7048 val_loss=0.3989 val_acc=0.8209
# [SqueezeNet 1.1 | seed 42] Epoch 2/15 | train_loss=0.3711 val_loss=0.4433 val_acc=0.8299
# [SqueezeNet 1.1 | seed 42] Epoch 3/15 | train_loss=0.2878 val_loss=0.2300 val_acc=0.8925
# [SqueezeNet 1.1 | seed 42] Epoch 4/15 | train_loss=0.2410 val_loss=0.2210 val_acc=0.9045
# [SqueezeNet 1.1 | seed 42] Epoch 5/15 | train_loss=0.2772 val_loss=0.2754 val_acc=0.9045
# [SqueezeNet 1.1 | seed 42] Epoch 6/15 | train_loss=0.2015 val_loss=0.1716 val_acc=0.9313
# [SqueezeNet 1.1 | seed 42] Epoch 7/15 | train_loss=0.1815 val_loss=0.2757 val_acc=0.8925
# [SqueezeNet 1.1 | seed 42] Epoch 8/15 | train_loss=0.1727 val_loss=0.2064 val_acc=0.9104
# [SqueezeNet 1.1 | seed 42] Epoch 9/15 | train_loss=0.1800 val_loss=0.1655 val_acc=0.9313
# [SqueezeNet 1.1 | seed 42] Epoch 10/15 | train_loss=0.1401 val_loss=0.1984 val_acc=0.9224
# [SqueezeNet 1.1 | seed 42] Epoch 11/15 | train_loss=0.1295 val_loss=0.1103 val_acc=0.9493
# [SqueezeNet 1.1 | seed 42] Epoch 12/15 | train_loss=0.1181 val_loss=0.1143 val_acc=0.9493
# [SqueezeNet 1.1 | seed 42] Epoch 13/15 | train_loss=0.1116 val_loss=0.1154 val_acc=0.9463
# [SqueezeNet 1.1 | seed 42] Epoch 14/15 | train_loss=0.1225 val_loss=0.1252 val_acc=0.9373
# [SqueezeNet 1.1 | seed 42] Epoch 15/15 | train_loss=0.0990 val_loss=0.1143 val_acc=0.9463
# [SqueezeNet 1.1 | seed 42] Test accuracy=0.9821 macro_F1=0.9828 macro_AUROC=0.9995
#
# ======================================================================
# SEED 123
# ======================================================================
# Split sizes -> train=1563 val=335 test=336 | train class counts=[555 580 428]
# [ResNet-50 | seed 123] Epoch 1/15 | train_loss=0.7319 val_loss=0.3974 val_acc=0.8627
# [ResNet-50 | seed 123] Epoch 2/15 | train_loss=0.2963 val_loss=0.1358 val_acc=0.9493
# [ResNet-50 | seed 123] Epoch 3/15 | train_loss=0.2032 val_loss=0.0954 val_acc=0.9672
# [ResNet-50 | seed 123] Epoch 4/15 | train_loss=0.1685 val_loss=0.0923 val_acc=0.9701
# [ResNet-50 | seed 123] Epoch 5/15 | train_loss=0.1378 val_loss=0.0651 val_acc=0.9821
# [ResNet-50 | seed 123] Epoch 6/15 | train_loss=0.1079 val_loss=0.0512 val_acc=0.9881
# [ResNet-50 | seed 123] Epoch 7/15 | train_loss=0.1034 val_loss=0.0551 val_acc=0.9821
# [ResNet-50 | seed 123] Epoch 8/15 | train_loss=0.0930 val_loss=0.0426 val_acc=0.9940
# [ResNet-50 | seed 123] Epoch 9/15 | train_loss=0.0977 val_loss=0.0503 val_acc=0.9761
# [ResNet-50 | seed 123] Epoch 10/15 | train_loss=0.0923 val_loss=0.0409 val_acc=0.9851
# [ResNet-50 | seed 123] Epoch 11/15 | train_loss=0.0579 val_loss=0.0303 val_acc=0.9881
# [ResNet-50 | seed 123] Epoch 12/15 | train_loss=0.0648 val_loss=0.0381 val_acc=0.9881
# [ResNet-50 | seed 123] Epoch 13/15 | train_loss=0.0551 val_loss=0.0436 val_acc=0.9851
# [ResNet-50 | seed 123] Epoch 14/15 | train_loss=0.0469 val_loss=0.0197 val_acc=0.9940
# [ResNet-50 | seed 123] Epoch 15/15 | train_loss=0.0602 val_loss=0.0401 val_acc=0.9821
# [ResNet-50 | seed 123] Test accuracy=0.9851 macro_F1=0.9849 macro_AUROC=0.9993
# [DenseNet-121 | seed 123] Epoch 1/15 | train_loss=0.7195 val_loss=0.4703 val_acc=0.8537
# [DenseNet-121 | seed 123] Epoch 2/15 | train_loss=0.4193 val_loss=0.3848 val_acc=0.8000
# [DenseNet-121 | seed 123] Epoch 3/15 | train_loss=0.2964 val_loss=0.2523 val_acc=0.8806
# [DenseNet-121 | seed 123] Epoch 4/15 | train_loss=0.2177 val_loss=0.1420 val_acc=0.9552
# [DenseNet-121 | seed 123] Epoch 5/15 | train_loss=0.2015 val_loss=0.1487 val_acc=0.9343
# [DenseNet-121 | seed 123] Epoch 6/15 | train_loss=0.1798 val_loss=0.1294 val_acc=0.9463
# [DenseNet-121 | seed 123] Epoch 7/15 | train_loss=0.1610 val_loss=0.1287 val_acc=0.9522
# [DenseNet-121 | seed 123] Epoch 8/15 | train_loss=0.1488 val_loss=0.0844 val_acc=0.9761
# [DenseNet-121 | seed 123] Epoch 9/15 | train_loss=0.1461 val_loss=0.0986 val_acc=0.9642
# [DenseNet-121 | seed 123] Epoch 10/15 | train_loss=0.1206 val_loss=0.0722 val_acc=0.9731
# [DenseNet-121 | seed 123] Epoch 11/15 | train_loss=0.1062 val_loss=0.0569 val_acc=0.9761
# [DenseNet-121 | seed 123] Epoch 12/15 | train_loss=0.1152 val_loss=0.0612 val_acc=0.9761
# [DenseNet-121 | seed 123] Epoch 13/15 | train_loss=0.0925 val_loss=0.0955 val_acc=0.9522
# [DenseNet-121 | seed 123] Epoch 14/15 | train_loss=0.0913 val_loss=0.0591 val_acc=0.9821
# [DenseNet-121 | seed 123] Epoch 15/15 | train_loss=0.0860 val_loss=0.0392 val_acc=0.9821
# [DenseNet-121 | seed 123] Test accuracy=0.9762 macro_F1=0.9759 macro_AUROC=0.9986
# [ViT-B/16 | seed 123] Epoch 1/15 | train_loss=0.6168 val_loss=0.3598 val_acc=0.8269
# [ViT-B/16 | seed 123] Epoch 2/15 | train_loss=0.2855 val_loss=0.2401 val_acc=0.8925
# [ViT-B/16 | seed 123] Epoch 3/15 | train_loss=0.2128 val_loss=0.1635 val_acc=0.9284
# [ViT-B/16 | seed 123] Epoch 4/15 | train_loss=0.1461 val_loss=0.1673 val_acc=0.9194
# [ViT-B/16 | seed 123] Epoch 5/15 | train_loss=0.1300 val_loss=0.1521 val_acc=0.9313
# [ViT-B/16 | seed 123] Epoch 6/15 | train_loss=0.1094 val_loss=0.2300 val_acc=0.9104
# [ViT-B/16 | seed 123] Epoch 7/15 | train_loss=0.0998 val_loss=0.0966 val_acc=0.9582
# [ViT-B/16 | seed 123] Epoch 8/15 | train_loss=0.0773 val_loss=0.0903 val_acc=0.9522
# [ViT-B/16 | seed 123] Epoch 9/15 | train_loss=0.0673 val_loss=0.0765 val_acc=0.9672
# [ViT-B/16 | seed 123] Epoch 10/15 | train_loss=0.0686 val_loss=0.0874 val_acc=0.9552
# [ViT-B/16 | seed 123] Epoch 11/15 | train_loss=0.0577 val_loss=0.0648 val_acc=0.9731
# [ViT-B/16 | seed 123] Epoch 12/15 | train_loss=0.0571 val_loss=0.0578 val_acc=0.9731
# [ViT-B/16 | seed 123] Epoch 13/15 | train_loss=0.0466 val_loss=0.0504 val_acc=0.9791
# [ViT-B/16 | seed 123] Epoch 14/15 | train_loss=0.0531 val_loss=0.0844 val_acc=0.9612
# [ViT-B/16 | seed 123] Epoch 15/15 | train_loss=0.0580 val_loss=0.0602 val_acc=0.9731
# [ViT-B/16 | seed 123] Test accuracy=0.9821 macro_F1=0.9821 macro_AUROC=0.9992
# [SqueezeNet 1.1 | seed 123] Epoch 1/15 | train_loss=0.8079 val_loss=0.4422 val_acc=0.8090
# [SqueezeNet 1.1 | seed 123] Epoch 2/15 | train_loss=0.4544 val_loss=0.3200 val_acc=0.8448
# [SqueezeNet 1.1 | seed 123] Epoch 3/15 | train_loss=0.3548 val_loss=0.1895 val_acc=0.9433
# [SqueezeNet 1.1 | seed 123] Epoch 4/15 | train_loss=0.2713 val_loss=0.1867 val_acc=0.9254
# [SqueezeNet 1.1 | seed 123] Epoch 5/15 | train_loss=0.2394 val_loss=0.1902 val_acc=0.9433
# [SqueezeNet 1.1 | seed 123] Epoch 6/15 | train_loss=0.1919 val_loss=0.1803 val_acc=0.9463
# [SqueezeNet 1.1 | seed 123] Epoch 7/15 | train_loss=0.2144 val_loss=0.1114 val_acc=0.9612
# [SqueezeNet 1.1 | seed 123] Epoch 8/15 | train_loss=0.1562 val_loss=0.1014 val_acc=0.9582
# [SqueezeNet 1.1 | seed 123] Epoch 9/15 | train_loss=0.1438 val_loss=0.1232 val_acc=0.9522
# [SqueezeNet 1.1 | seed 123] Epoch 10/15 | train_loss=0.1576 val_loss=0.1513 val_acc=0.9313
# [SqueezeNet 1.1 | seed 123] Epoch 11/15 | train_loss=0.1265 val_loss=0.1369 val_acc=0.9463
# [SqueezeNet 1.1 | seed 123] Epoch 12/15 | train_loss=0.1106 val_loss=0.0744 val_acc=0.9642
# [SqueezeNet 1.1 | seed 123] Epoch 13/15 | train_loss=0.0887 val_loss=0.0676 val_acc=0.9731
# [SqueezeNet 1.1 | seed 123] Epoch 14/15 | train_loss=0.0984 val_loss=0.0630 val_acc=0.9731
# [SqueezeNet 1.1 | seed 123] Epoch 15/15 | train_loss=0.1047 val_loss=0.0645 val_acc=0.9731
# [SqueezeNet 1.1 | seed 123] Test accuracy=0.9702 macro_F1=0.9703 macro_AUROC=0.9991
#
# ======================================================================
# SEED 2024
# ======================================================================
# Split sizes -> train=1563 val=335 test=336 | train class counts=[578 550 435]
# [ResNet-50 | seed 2024] Epoch 1/15 | train_loss=0.7486 val_loss=0.4152 val_acc=0.8507
# [ResNet-50 | seed 2024] Epoch 2/15 | train_loss=0.2740 val_loss=0.1791 val_acc=0.9552
# [ResNet-50 | seed 2024] Epoch 3/15 | train_loss=0.1836 val_loss=0.1154 val_acc=0.9731
# [ResNet-50 | seed 2024] Epoch 4/15 | train_loss=0.1416 val_loss=0.1039 val_acc=0.9582
# [ResNet-50 | seed 2024] Epoch 5/15 | train_loss=0.1229 val_loss=0.0920 val_acc=0.9642
# [ResNet-50 | seed 2024] Epoch 6/15 | train_loss=0.1093 val_loss=0.0697 val_acc=0.9731
# [ResNet-50 | seed 2024] Epoch 7/15 | train_loss=0.1136 val_loss=0.0640 val_acc=0.9821
# [ResNet-50 | seed 2024] Epoch 8/15 | train_loss=0.0864 val_loss=0.0479 val_acc=0.9881
# [ResNet-50 | seed 2024] Epoch 9/15 | train_loss=0.0777 val_loss=0.0637 val_acc=0.9851
# [ResNet-50 | seed 2024] Epoch 10/15 | train_loss=0.0728 val_loss=0.0487 val_acc=0.9731
# [ResNet-50 | seed 2024] Epoch 11/15 | train_loss=0.0624 val_loss=0.0471 val_acc=0.9851
# [ResNet-50 | seed 2024] Epoch 12/15 | train_loss=0.0628 val_loss=0.0530 val_acc=0.9881
# [ResNet-50 | seed 2024] Epoch 13/15 | train_loss=0.0512 val_loss=0.0424 val_acc=0.9791
# [ResNet-50 | seed 2024] Epoch 14/15 | train_loss=0.0736 val_loss=0.0390 val_acc=0.9791
# [ResNet-50 | seed 2024] Epoch 15/15 | train_loss=0.0487 val_loss=0.0453 val_acc=0.9881
# [ResNet-50 | seed 2024] Test accuracy=0.9732 macro_F1=0.9743 macro_AUROC=0.9958
# [DenseNet-121 | seed 2024] Epoch 1/15 | train_loss=0.7278 val_loss=0.4483 val_acc=0.8657
# [DenseNet-121 | seed 2024] Epoch 2/15 | train_loss=0.4172 val_loss=0.3124 val_acc=0.8836
# [DenseNet-121 | seed 2024] Epoch 3/15 | train_loss=0.2936 val_loss=0.1884 val_acc=0.9313
# [DenseNet-121 | seed 2024] Epoch 4/15 | train_loss=0.2505 val_loss=0.1461 val_acc=0.9612
# [DenseNet-121 | seed 2024] Epoch 5/15 | train_loss=0.1977 val_loss=0.1342 val_acc=0.9493
# [DenseNet-121 | seed 2024] Epoch 6/15 | train_loss=0.1788 val_loss=0.0981 val_acc=0.9672
# [DenseNet-121 | seed 2024] Epoch 7/15 | train_loss=0.1555 val_loss=0.1259 val_acc=0.9612
# [DenseNet-121 | seed 2024] Epoch 8/15 | train_loss=0.1411 val_loss=0.0847 val_acc=0.9701
# [DenseNet-121 | seed 2024] Epoch 9/15 | train_loss=0.1501 val_loss=0.0776 val_acc=0.9701
# [DenseNet-121 | seed 2024] Epoch 10/15 | train_loss=0.1231 val_loss=0.0706 val_acc=0.9761
# [DenseNet-121 | seed 2024] Epoch 11/15 | train_loss=0.1230 val_loss=0.0811 val_acc=0.9672
# [DenseNet-121 | seed 2024] Epoch 12/15 | train_loss=0.1172 val_loss=0.0577 val_acc=0.9731
# [DenseNet-121 | seed 2024] Epoch 13/15 | train_loss=0.0884 val_loss=0.0542 val_acc=0.9791
# [DenseNet-121 | seed 2024] Epoch 14/15 | train_loss=0.0956 val_loss=0.0542 val_acc=0.9761
# [DenseNet-121 | seed 2024] Epoch 15/15 | train_loss=0.0866 val_loss=0.0487 val_acc=0.9791
# [DenseNet-121 | seed 2024] Test accuracy=0.9702 macro_F1=0.9721 macro_AUROC=0.9927
# [ViT-B/16 | seed 2024] Epoch 1/15 | train_loss=0.6246 val_loss=0.3609 val_acc=0.8627
# [ViT-B/16 | seed 2024] Epoch 2/15 | train_loss=0.2707 val_loss=0.2019 val_acc=0.8955
# [ViT-B/16 | seed 2024] Epoch 3/15 | train_loss=0.1873 val_loss=0.2014 val_acc=0.9134
# [ViT-B/16 | seed 2024] Epoch 4/15 | train_loss=0.1470 val_loss=0.1962 val_acc=0.9164
# [ViT-B/16 | seed 2024] Epoch 5/15 | train_loss=0.1322 val_loss=0.1205 val_acc=0.9522
# [ViT-B/16 | seed 2024] Epoch 6/15 | train_loss=0.1416 val_loss=0.1107 val_acc=0.9522
# [ViT-B/16 | seed 2024] Epoch 7/15 | train_loss=0.0980 val_loss=0.1100 val_acc=0.9433
# [ViT-B/16 | seed 2024] Epoch 8/15 | train_loss=0.0807 val_loss=0.0909 val_acc=0.9612
# [ViT-B/16 | seed 2024] Epoch 9/15 | train_loss=0.0784 val_loss=0.1038 val_acc=0.9582
# [ViT-B/16 | seed 2024] Epoch 10/15 | train_loss=0.0657 val_loss=0.0807 val_acc=0.9701
# [ViT-B/16 | seed 2024] Epoch 11/15 | train_loss=0.0664 val_loss=0.0840 val_acc=0.9582
# [ViT-B/16 | seed 2024] Epoch 12/15 | train_loss=0.0606 val_loss=0.0763 val_acc=0.9731
# [ViT-B/16 | seed 2024] Epoch 13/15 | train_loss=0.0617 val_loss=0.0775 val_acc=0.9582
# [ViT-B/16 | seed 2024] Epoch 14/15 | train_loss=0.0506 val_loss=0.0546 val_acc=0.9672
# [ViT-B/16 | seed 2024] Epoch 15/15 | train_loss=0.0533 val_loss=0.0471 val_acc=0.9821
# [ViT-B/16 | seed 2024] Test accuracy=0.9613 macro_F1=0.9641 macro_AUROC=0.9954
# [SqueezeNet 1.1 | seed 2024] Epoch 1/15 | train_loss=0.6686 val_loss=0.4265 val_acc=0.7940
# [SqueezeNet 1.1 | seed 2024] Epoch 2/15 | train_loss=0.3465 val_loss=0.3282 val_acc=0.9045
# [SqueezeNet 1.1 | seed 2024] Epoch 3/15 | train_loss=0.2634 val_loss=0.1677 val_acc=0.9254
# [SqueezeNet 1.1 | seed 2024] Epoch 4/15 | train_loss=0.2494 val_loss=0.2125 val_acc=0.8985
# [SqueezeNet 1.1 | seed 2024] Epoch 5/15 | train_loss=0.1985 val_loss=0.1709 val_acc=0.9284
# [SqueezeNet 1.1 | seed 2024] Epoch 6/15 | train_loss=0.2148 val_loss=0.3053 val_acc=0.8836
# [SqueezeNet 1.1 | seed 2024] Epoch 7/15 | train_loss=0.1465 val_loss=0.1188 val_acc=0.9373
# [SqueezeNet 1.1 | seed 2024] Epoch 8/15 | train_loss=0.1259 val_loss=0.1188 val_acc=0.9522
# [SqueezeNet 1.1 | seed 2024] Epoch 9/15 | train_loss=0.1262 val_loss=0.1091 val_acc=0.9433
# [SqueezeNet 1.1 | seed 2024] Epoch 10/15 | train_loss=0.1220 val_loss=0.0811 val_acc=0.9642
# [SqueezeNet 1.1 | seed 2024] Epoch 11/15 | train_loss=0.0930 val_loss=0.0749 val_acc=0.9642
# [SqueezeNet 1.1 | seed 2024] Epoch 12/15 | train_loss=0.1110 val_loss=0.1377 val_acc=0.9493
# [SqueezeNet 1.1 | seed 2024] Epoch 13/15 | train_loss=0.1074 val_loss=0.0866 val_acc=0.9612
# [SqueezeNet 1.1 | seed 2024] Epoch 14/15 | train_loss=0.1087 val_loss=0.0945 val_acc=0.9522
# [SqueezeNet 1.1 | seed 2024] Epoch 15/15 | train_loss=0.0896 val_loss=0.1271 val_acc=0.9493
# [SqueezeNet 1.1 | seed 2024] Test accuracy=0.9464 macro_F1=0.9514 macro_AUROC=0.9957
#
# ======================================================================
# SEED 7
# ======================================================================
# Split sizes -> train=1563 val=335 test=336 | train class counts=[543 566 454]
# [ResNet-50 | seed 7] Epoch 1/15 | train_loss=0.7241 val_loss=0.3426 val_acc=0.8836
# [ResNet-50 | seed 7] Epoch 2/15 | train_loss=0.2693 val_loss=0.1362 val_acc=0.9582
# [ResNet-50 | seed 7] Epoch 3/15 | train_loss=0.1984 val_loss=0.1538 val_acc=0.9224
# [ResNet-50 | seed 7] Epoch 4/15 | train_loss=0.1599 val_loss=0.1422 val_acc=0.9403
# [ResNet-50 | seed 7] Epoch 5/15 | train_loss=0.1232 val_loss=0.1086 val_acc=0.9493
# [ResNet-50 | seed 7] Epoch 6/15 | train_loss=0.1386 val_loss=0.0979 val_acc=0.9612
# [ResNet-50 | seed 7] Epoch 7/15 | train_loss=0.0998 val_loss=0.0649 val_acc=0.9821
# [ResNet-50 | seed 7] Epoch 8/15 | train_loss=0.1046 val_loss=0.0602 val_acc=0.9851
# [ResNet-50 | seed 7] Epoch 9/15 | train_loss=0.0823 val_loss=0.0682 val_acc=0.9761
# [ResNet-50 | seed 7] Epoch 10/15 | train_loss=0.0608 val_loss=0.0546 val_acc=0.9821
# [ResNet-50 | seed 7] Epoch 11/15 | train_loss=0.0769 val_loss=0.0517 val_acc=0.9851
# [ResNet-50 | seed 7] Epoch 12/15 | train_loss=0.0686 val_loss=0.0528 val_acc=0.9821
# [ResNet-50 | seed 7] Epoch 13/15 | train_loss=0.0579 val_loss=0.0528 val_acc=0.9881
# [ResNet-50 | seed 7] Epoch 14/15 | train_loss=0.0637 val_loss=0.0575 val_acc=0.9821
# [ResNet-50 | seed 7] Epoch 15/15 | train_loss=0.0471 val_loss=0.0539 val_acc=0.9851
# [ResNet-50 | seed 7] Test accuracy=0.9762 macro_F1=0.9765 macro_AUROC=0.9984
# [DenseNet-121 | seed 7] Epoch 1/15 | train_loss=0.7478 val_loss=0.4495 val_acc=0.8836
# [DenseNet-121 | seed 7] Epoch 2/15 | train_loss=0.4091 val_loss=0.2557 val_acc=0.9134
# [DenseNet-121 | seed 7] Epoch 3/15 | train_loss=0.2848 val_loss=0.2475 val_acc=0.9104
# [DenseNet-121 | seed 7] Epoch 4/15 | train_loss=0.2450 val_loss=0.1531 val_acc=0.9463
# [DenseNet-121 | seed 7] Epoch 5/15 | train_loss=0.2057 val_loss=0.1433 val_acc=0.9582
# [DenseNet-121 | seed 7] Epoch 6/15 | train_loss=0.1697 val_loss=0.1201 val_acc=0.9522
# [DenseNet-121 | seed 7] Epoch 7/15 | train_loss=0.1564 val_loss=0.1039 val_acc=0.9642
# [DenseNet-121 | seed 7] Epoch 8/15 | train_loss=0.1401 val_loss=0.1128 val_acc=0.9612
# [DenseNet-121 | seed 7] Epoch 9/15 | train_loss=0.1382 val_loss=0.1087 val_acc=0.9612
# [DenseNet-121 | seed 7] Epoch 10/15 | train_loss=0.1124 val_loss=0.0873 val_acc=0.9642
# [DenseNet-121 | seed 7] Epoch 11/15 | train_loss=0.1238 val_loss=0.0727 val_acc=0.9821
# [DenseNet-121 | seed 7] Epoch 12/15 | train_loss=0.1200 val_loss=0.0911 val_acc=0.9731
# [DenseNet-121 | seed 7] Epoch 13/15 | train_loss=0.1029 val_loss=0.1059 val_acc=0.9612
# [DenseNet-121 | seed 7] Epoch 14/15 | train_loss=0.1277 val_loss=0.1001 val_acc=0.9642
# [DenseNet-121 | seed 7] Epoch 15/15 | train_loss=0.0914 val_loss=0.0653 val_acc=0.9761
# [DenseNet-121 | seed 7] Test accuracy=0.9643 macro_F1=0.9654 macro_AUROC=0.9970
# [ViT-B/16 | seed 7] Epoch 1/15 | train_loss=0.6706 val_loss=0.3056 val_acc=0.8925
# [ViT-B/16 | seed 7] Epoch 2/15 | train_loss=0.2864 val_loss=0.1989 val_acc=0.9254
# [ViT-B/16 | seed 7] Epoch 3/15 | train_loss=0.1971 val_loss=0.1848 val_acc=0.9194
# [ViT-B/16 | seed 7] Epoch 4/15 | train_loss=0.1395 val_loss=0.1363 val_acc=0.9522
# [ViT-B/16 | seed 7] Epoch 5/15 | train_loss=0.1289 val_loss=0.1626 val_acc=0.9343
# [ViT-B/16 | seed 7] Epoch 6/15 | train_loss=0.1219 val_loss=0.1201 val_acc=0.9642
# [ViT-B/16 | seed 7] Epoch 7/15 | train_loss=0.1005 val_loss=0.1169 val_acc=0.9612
# [ViT-B/16 | seed 7] Epoch 8/15 | train_loss=0.0889 val_loss=0.0985 val_acc=0.9731
# [ViT-B/16 | seed 7] Epoch 9/15 | train_loss=0.0854 val_loss=0.0873 val_acc=0.9672
# [ViT-B/16 | seed 7] Epoch 10/15 | train_loss=0.0676 val_loss=0.0888 val_acc=0.9731
# [ViT-B/16 | seed 7] Epoch 11/15 | train_loss=0.0688 val_loss=0.0909 val_acc=0.9672
# [ViT-B/16 | seed 7] Epoch 12/15 | train_loss=0.0647 val_loss=0.0803 val_acc=0.9701
# [ViT-B/16 | seed 7] Epoch 13/15 | train_loss=0.0473 val_loss=0.1428 val_acc=0.9433
# [ViT-B/16 | seed 7] Epoch 14/15 | train_loss=0.0607 val_loss=0.0767 val_acc=0.9731
# [ViT-B/16 | seed 7] Epoch 15/15 | train_loss=0.0489 val_loss=0.0737 val_acc=0.9791
# [ViT-B/16 | seed 7] Test accuracy=0.9792 macro_F1=0.9800 macro_AUROC=0.9985
# [SqueezeNet 1.1 | seed 7] Epoch 1/15 | train_loss=0.6918 val_loss=0.3734 val_acc=0.8478
# [SqueezeNet 1.1 | seed 7] Epoch 2/15 | train_loss=0.4012 val_loss=0.3481 val_acc=0.8776
# [SqueezeNet 1.1 | seed 7] Epoch 3/15 | train_loss=0.3406 val_loss=0.2365 val_acc=0.9104
# [SqueezeNet 1.1 | seed 7] Epoch 4/15 | train_loss=0.2333 val_loss=0.2567 val_acc=0.9134
# [SqueezeNet 1.1 | seed 7] Epoch 5/15 | train_loss=0.2314 val_loss=0.1522 val_acc=0.9403
# [SqueezeNet 1.1 | seed 7] Epoch 6/15 | train_loss=0.2210 val_loss=0.1665 val_acc=0.9433
# [SqueezeNet 1.1 | seed 7] Epoch 7/15 | train_loss=0.1974 val_loss=0.1533 val_acc=0.9343
# [SqueezeNet 1.1 | seed 7] Epoch 8/15 | train_loss=0.1639 val_loss=0.1348 val_acc=0.9433
# [SqueezeNet 1.1 | seed 7] Epoch 9/15 | train_loss=0.1416 val_loss=0.1221 val_acc=0.9522
# [SqueezeNet 1.1 | seed 7] Epoch 10/15 | train_loss=0.1475 val_loss=0.2318 val_acc=0.9104
# [SqueezeNet 1.1 | seed 7] Epoch 11/15 | train_loss=0.1895 val_loss=0.0918 val_acc=0.9672
# [SqueezeNet 1.1 | seed 7] Epoch 12/15 | train_loss=0.1452 val_loss=0.1212 val_acc=0.9522
# [SqueezeNet 1.1 | seed 7] Epoch 13/15 | train_loss=0.1173 val_loss=0.1564 val_acc=0.9463
# [SqueezeNet 1.1 | seed 7] Epoch 14/15 | train_loss=0.1063 val_loss=0.0909 val_acc=0.9552
# [SqueezeNet 1.1 | seed 7] Epoch 15/15 | train_loss=0.1208 val_loss=0.1675 val_acc=0.9194
# [SqueezeNet 1.1 | seed 7] Test accuracy=0.9226 macro_F1=0.9266 macro_AUROC=0.9972
#
# ======================================================================
# SEED 1000
# ======================================================================
# Split sizes -> train=1563 val=335 test=336 | train class counts=[556 554 453]
# [ResNet-50 | seed 1000] Epoch 1/15 | train_loss=0.7354 val_loss=0.3623 val_acc=0.8925
# [ResNet-50 | seed 1000] Epoch 2/15 | train_loss=0.2827 val_loss=0.2599 val_acc=0.8806
# [ResNet-50 | seed 1000] Epoch 3/15 | train_loss=0.1907 val_loss=0.1587 val_acc=0.9552
# [ResNet-50 | seed 1000] Epoch 4/15 | train_loss=0.1543 val_loss=0.1545 val_acc=0.9493
# [ResNet-50 | seed 1000] Epoch 5/15 | train_loss=0.1256 val_loss=0.1149 val_acc=0.9552
# [ResNet-50 | seed 1000] Epoch 6/15 | train_loss=0.1097 val_loss=0.1268 val_acc=0.9522
# [ResNet-50 | seed 1000] Epoch 7/15 | train_loss=0.0854 val_loss=0.1254 val_acc=0.9552
# [ResNet-50 | seed 1000] Epoch 8/15 | train_loss=0.0682 val_loss=0.1067 val_acc=0.9731
# [ResNet-50 | seed 1000] Epoch 9/15 | train_loss=0.0622 val_loss=0.1268 val_acc=0.9612
# [ResNet-50 | seed 1000] Epoch 10/15 | train_loss=0.0722 val_loss=0.1168 val_acc=0.9672
# [ResNet-50 | seed 1000] Epoch 11/15 | train_loss=0.0638 val_loss=0.0881 val_acc=0.9612
# [ResNet-50 | seed 1000] Epoch 12/15 | train_loss=0.0495 val_loss=0.0967 val_acc=0.9761
# [ResNet-50 | seed 1000] Epoch 13/15 | train_loss=0.0435 val_loss=0.1073 val_acc=0.9791
# [ResNet-50 | seed 1000] Epoch 14/15 | train_loss=0.0657 val_loss=0.1054 val_acc=0.9791
# [ResNet-50 | seed 1000] Epoch 15/15 | train_loss=0.0437 val_loss=0.1027 val_acc=0.9791
# [ResNet-50 | seed 1000] Test accuracy=0.9762 macro_F1=0.9777 macro_AUROC=0.9957
# [DenseNet-121 | seed 1000] Epoch 1/15 | train_loss=0.7113 val_loss=0.4997 val_acc=0.8299
# [DenseNet-121 | seed 1000] Epoch 2/15 | train_loss=0.4376 val_loss=0.3344 val_acc=0.8746
# [DenseNet-121 | seed 1000] Epoch 3/15 | train_loss=0.2947 val_loss=0.2537 val_acc=0.9104
# [DenseNet-121 | seed 1000] Epoch 4/15 | train_loss=0.2403 val_loss=0.2019 val_acc=0.9313
# [DenseNet-121 | seed 1000] Epoch 5/15 | train_loss=0.1828 val_loss=0.1716 val_acc=0.9373
# [DenseNet-121 | seed 1000] Epoch 6/15 | train_loss=0.1515 val_loss=0.1445 val_acc=0.9463
# [DenseNet-121 | seed 1000] Epoch 7/15 | train_loss=0.1369 val_loss=0.1465 val_acc=0.9522
# [DenseNet-121 | seed 1000] Epoch 8/15 | train_loss=0.1170 val_loss=0.1573 val_acc=0.9403
# [DenseNet-121 | seed 1000] Epoch 9/15 | train_loss=0.1076 val_loss=0.1563 val_acc=0.9582
# [DenseNet-121 | seed 1000] Epoch 10/15 | train_loss=0.1303 val_loss=0.1604 val_acc=0.9433
# [DenseNet-121 | seed 1000] Epoch 11/15 | train_loss=0.1128 val_loss=0.1399 val_acc=0.9642
# [DenseNet-121 | seed 1000] Epoch 12/15 | train_loss=0.0894 val_loss=0.1648 val_acc=0.9642
# [DenseNet-121 | seed 1000] Epoch 13/15 | train_loss=0.0738 val_loss=0.1263 val_acc=0.9612
# [DenseNet-121 | seed 1000] Epoch 14/15 | train_loss=0.0941 val_loss=0.1480 val_acc=0.9552
# [DenseNet-121 | seed 1000] Epoch 15/15 | train_loss=0.0839 val_loss=0.1560 val_acc=0.9522
# [DenseNet-121 | seed 1000] Test accuracy=0.9583 macro_F1=0.9614 macro_AUROC=0.9927
# [ViT-B/16 | seed 1000] Epoch 1/15 | train_loss=0.6493 val_loss=0.3955 val_acc=0.8299
# [ViT-B/16 | seed 1000] Epoch 2/15 | train_loss=0.2689 val_loss=0.2484 val_acc=0.8806
# [ViT-B/16 | seed 1000] Epoch 3/15 | train_loss=0.1871 val_loss=0.2478 val_acc=0.9104
# [ViT-B/16 | seed 1000] Epoch 4/15 | train_loss=0.1522 val_loss=0.1618 val_acc=0.9284
# [ViT-B/16 | seed 1000] Epoch 5/15 | train_loss=0.1168 val_loss=0.1849 val_acc=0.9164
# [ViT-B/16 | seed 1000] Epoch 6/15 | train_loss=0.1309 val_loss=0.1326 val_acc=0.9313
# [ViT-B/16 | seed 1000] Epoch 7/15 | train_loss=0.0962 val_loss=0.1511 val_acc=0.9403
# [ViT-B/16 | seed 1000] Epoch 8/15 | train_loss=0.0857 val_loss=0.1305 val_acc=0.9552
# [ViT-B/16 | seed 1000] Epoch 9/15 | train_loss=0.0823 val_loss=0.1339 val_acc=0.9463
# [ViT-B/16 | seed 1000] Epoch 10/15 | train_loss=0.0729 val_loss=0.1162 val_acc=0.9522
# [ViT-B/16 | seed 1000] Epoch 11/15 | train_loss=0.0558 val_loss=0.1556 val_acc=0.9463
# [ViT-B/16 | seed 1000] Epoch 12/15 | train_loss=0.0551 val_loss=0.1066 val_acc=0.9612
# [ViT-B/16 | seed 1000] Epoch 13/15 | train_loss=0.0393 val_loss=0.1240 val_acc=0.9522
# [ViT-B/16 | seed 1000] Epoch 14/15 | train_loss=0.0536 val_loss=0.1149 val_acc=0.9522
# [ViT-B/16 | seed 1000] Epoch 15/15 | train_loss=0.0450 val_loss=0.1082 val_acc=0.9672
# [ViT-B/16 | seed 1000] Test accuracy=0.9643 macro_F1=0.9668 macro_AUROC=0.9973
# [SqueezeNet 1.1 | seed 1000] Epoch 1/15 | train_loss=0.7432 val_loss=0.5302 val_acc=0.7881
# [SqueezeNet 1.1 | seed 1000] Epoch 2/15 | train_loss=0.4029 val_loss=0.3883 val_acc=0.8537
# [SqueezeNet 1.1 | seed 1000] Epoch 3/15 | train_loss=0.2794 val_loss=0.3327 val_acc=0.8597
# [SqueezeNet 1.1 | seed 1000] Epoch 4/15 | train_loss=0.2671 val_loss=0.2204 val_acc=0.8955
# [SqueezeNet 1.1 | seed 1000] Epoch 5/15 | train_loss=0.2324 val_loss=0.3291 val_acc=0.8866
# [SqueezeNet 1.1 | seed 1000] Epoch 6/15 | train_loss=0.1692 val_loss=0.1535 val_acc=0.9343
# [SqueezeNet 1.1 | seed 1000] Epoch 7/15 | train_loss=0.1696 val_loss=0.2419 val_acc=0.9104
# [SqueezeNet 1.1 | seed 1000] Epoch 8/15 | train_loss=0.1688 val_loss=0.2230 val_acc=0.9134
# [SqueezeNet 1.1 | seed 1000] Epoch 9/15 | train_loss=0.1403 val_loss=0.2195 val_acc=0.9164
# [SqueezeNet 1.1 | seed 1000] Epoch 10/15 | train_loss=0.1163 val_loss=0.1782 val_acc=0.9403
# [SqueezeNet 1.1 | seed 1000] Epoch 11/15 | train_loss=0.0963 val_loss=0.1328 val_acc=0.9493
# [SqueezeNet 1.1 | seed 1000] Epoch 12/15 | train_loss=0.1047 val_loss=0.1460 val_acc=0.9463
# [SqueezeNet 1.1 | seed 1000] Epoch 13/15 | train_loss=0.0916 val_loss=0.1209 val_acc=0.9552
# [SqueezeNet 1.1 | seed 1000] Epoch 14/15 | train_loss=0.0904 val_loss=0.1289 val_acc=0.9522
# [SqueezeNet 1.1 | seed 1000] Epoch 15/15 | train_loss=0.0869 val_loss=0.1092 val_acc=0.9522
# [SqueezeNet 1.1 | seed 1000] Test accuracy=0.9583 macro_F1=0.9617 macro_AUROC=0.9957
#
# All seeds complete.

# %%
# 7. Raw per-seed results table
import pandas as pd

results_df = pd.DataFrame(all_results)
results_df.to_csv('multiseed_raw_results.csv', index=False)
print("Raw per-seed results saved to 'multiseed_raw_results.csv'")
results_df
# Out:
# Raw per-seed results saved to 'multiseed_raw_results.csv'
#     seed           model  accuracy  precision_macro  recall_macro  f1_macro  \
# 0     42       ResNet-50  0.988095         0.987912      0.988647  0.988226
# 1     42    DenseNet-121  0.979167         0.979586      0.980392  0.979509
# 2     42        ViT-B/16  0.985119         0.985702      0.985038  0.985314
# 3     42  SqueezeNet 1.1  0.982143         0.983193      0.983193  0.982759
# 4    123       ResNet-50  0.985119         0.985302      0.984644  0.984873
# 5    123    DenseNet-121  0.976190         0.976099      0.975805  0.975940
# 6    123        ViT-B/16  0.982143         0.982893      0.981613  0.982137
# 7    123  SqueezeNet 1.1  0.970238         0.970236      0.971236  0.970283
# 8   2024       ResNet-50  0.973214         0.972778      0.976068  0.974299
# 9   2024    DenseNet-121  0.970238         0.972087      0.972863  0.972146
# 10  2024        ViT-B/16  0.961310         0.965090      0.964530  0.964066
# 11  2024  SqueezeNet 1.1  0.946429         0.959459      0.950000  0.951390
# 12     7       ResNet-50  0.976190         0.976697      0.976412  0.976467
# 13     7    DenseNet-121  0.964286         0.965195      0.965629  0.965371
# 14     7        ViT-B/16  0.979167         0.980730      0.979610  0.980007
# 15     7  SqueezeNet 1.1  0.922619         0.944999      0.921719  0.926562
# 16  1000       ResNet-50  0.976190         0.977433      0.978096  0.977683
# 17  1000    DenseNet-121  0.958333         0.962666      0.960743  0.961376
# 18  1000        ViT-B/16  0.964286         0.968123      0.966208  0.966834
# 19  1000  SqueezeNet 1.1  0.958333         0.961860      0.961701  0.961738
#
#     auroc_macro  total_params  trainable_params
# 0      0.998161      23514179          14970883
# 1      0.999518       6956931           2163203
# 2      0.998385      85800963           7091715
# 3      0.999504        724035            724035
# 4      0.999302      23514179          14970883
# 5      0.998600       6956931           2163203
# 6      0.999213      85800963           7091715
# 7      0.999052        724035            724035
# 8      0.995840      23514179          14970883
# 9      0.992714       6956931           2163203
# 10     0.995366      85800963           7091715
# 11     0.995673        724035            724035
# 12     0.998368      23514179          14970883
# 13     0.996992       6956931           2163203
# 14     0.998457      85800963           7091715
# 15     0.997178        724035            724035
# 16     0.995696      23514179          14970883
# 17     0.992694       6956931           2163203
# 18     0.997321      85800963           7091715
# 19     0.995749        724035            724035

# %%
# 8. Mean +/- std summary per model, across all seeds

summary_rows = []
for model_name in MODEL_LIST:
    sub = results_df[results_df['model'] == model_name]
    row = {'Model': model_name, 'N Seeds': len(sub)}
    for metric in ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'auroc_macro']:
        row[f'{metric}_mean'] = sub[metric].mean()
        row[f'{metric}_std'] = sub[metric].std(ddof=1) if len(sub) > 1 else 0.0
    summary_rows.append(row)

summary_df = pd.DataFrame(summary_rows)
summary_df.to_csv('multiseed_summary_mean_std.csv', index=False)
print("Mean +/- std summary saved to 'multiseed_summary_mean_std.csv'")

# A compact, paper-ready "mean +/- std" display
display_df = summary_df.copy()
for metric in ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'auroc_macro']:
    display_df[metric.replace('_macro', '').capitalize()] = (
        display_df[f'{metric}_mean'].map('{:.4f}'.format) + ' \u00b1 ' + display_df[f'{metric}_std'].map('{:.4f}'.format)
    )
display_df = display_df[['Model', 'N Seeds', 'Accuracy', 'Precision', 'Recall', 'F1', 'Auroc']]
display_df
# Out:
# Mean +/- std summary saved to 'multiseed_summary_mean_std.csv'
#             Model  N Seeds         Accuracy        Precision           Recall  \
# 0       ResNet-50        5  0.9798 ± 0.0065  0.9800 ± 0.0063  0.9808 ± 0.0056
# 1    DenseNet-121        5  0.9696 ± 0.0085  0.9711 ± 0.0071  0.9711 ± 0.0079
# 2        ViT-B/16        5  0.9744 ± 0.0109  0.9765 ± 0.0093  0.9754 ± 0.0094
# 3  SqueezeNet 1.1        5  0.9560 ± 0.0229  0.9639 ± 0.0141  0.9576 ± 0.0235
#
#                 F1            Auroc
# 0  0.9803 ± 0.0059  0.9975 ± 0.0016
# 1  0.9709 ± 0.0075  0.9961 ± 0.0032
# 2  0.9757 ± 0.0096  0.9977 ± 0.0015
# 3  0.9585 ± 0.0213  0.9974 ± 0.0018

# %%
# 9. Paired significance testing across seeds (test accuracy), every model pair
from scipy import stats
from itertools import combinations

pval_rows = []
for m1, m2 in combinations(MODEL_LIST, 2):
    acc1 = results_df[results_df['model'] == m1].sort_values('seed')['accuracy'].values
    acc2 = results_df[results_df['model'] == m2].sort_values('seed')['accuracy'].values
    if len(acc1) == len(acc2) and len(acc1) > 1:
        t_stat, p_val = stats.ttest_rel(acc1, acc2)
    else:
        t_stat, p_val = np.nan, np.nan
    pval_rows.append({
        'Model A': m1, 'Model B': m2,
        'Mean Acc. A': acc1.mean(), 'Mean Acc. B': acc2.mean(),
        't-statistic': t_stat, 'p-value': p_val,
        'Significant (p<0.05)': (p_val < 0.05) if not np.isnan(p_val) else 'N/A'
    })

pval_df = pd.DataFrame(pval_rows)
pval_df.to_csv('multiseed_pairwise_significance.csv', index=False)
print("Pairwise paired t-test results (test accuracy across seeds) saved to 'multiseed_pairwise_significance.csv'")
print("NOTE: with N seeds this small, only large, consistent gaps will reach p<0.05 -- treat")
print("      non-significant results as 'insufficient evidence of a difference', not 'proven equal'.")
pval_df
# Out:
# Pairwise paired t-test results (test accuracy across seeds) saved to 'multiseed_pairwise_significance.csv'
# NOTE: with N seeds this small, only large, consistent gaps will reach p<0.05 -- treat
#       non-significant results as 'insufficient evidence of a difference', not 'proven equal'.
#         Model A         Model B  Mean Acc. A  Mean Acc. B  t-statistic  \
# 0     ResNet-50    DenseNet-121     0.979762     0.969643     4.185111
# 1     ResNet-50        ViT-B/16     0.979762     0.974405     1.856558
# 2     ResNet-50  SqueezeNet 1.1     0.979762     0.955952     2.921187
# 3  DenseNet-121        ViT-B/16     0.969643     0.974405    -1.241841
# 4  DenseNet-121  SqueezeNet 1.1     0.969643     0.955952     1.630427
# 5      ViT-B/16  SqueezeNet 1.1     0.974405     0.955952     1.891862
#
#     p-value  Significant (p<0.05)
# 0  0.013861                  True
# 1  0.136945                 False
# 2  0.043192                  True
# 3  0.282135                 False
# 4  0.178345                 False
# 5  0.131468                 False

# %%
# 10. Mean +/- std accuracy plot across seeds, per model

fig, ax = plt.subplots(figsize=(8, 6))
colors = {'ResNet-50': '#1f77b4', 'DenseNet-121': '#2ca02c', 'ViT-B/16': '#9467bd', 'SqueezeNet 1.1': '#d62728'}

means = [summary_df.loc[summary_df['Model'] == m, 'accuracy_mean'].values[0] for m in MODEL_LIST]
stds = [summary_df.loc[summary_df['Model'] == m, 'accuracy_std'].values[0] for m in MODEL_LIST]

ax.bar(MODEL_LIST, means, yerr=stds, capsize=8,
       color=[colors[m] for m in MODEL_LIST], alpha=0.85, edgecolor='black')
ax.set_ylabel('Test Accuracy (mean \u00b1 std across seeds)', fontsize=11)
ax.set_title(f'Multi-Seed Test Accuracy (N={len(SEEDS)} seeds)', fontsize=13, fontweight='bold')
ax.set_ylim(min(means) - 3 * max(stds) - 0.02, 1.0)
for i, (m, s) in enumerate(zip(means, stds)):
    ax.text(i, m + s + 0.003, f'{m:.4f}\n\u00b1{s:.4f}', ha='center', fontsize=9)
plt.grid(axis='y', linestyle=':', alpha=0.5)
plt.tight_layout()
plt.savefig('multiseed_accuracy_comparison.png', dpi=300)
plt.show()
print("Saved to 'multiseed_accuracy_comparison.png'")
# Out:
# Saved to 'multiseed_accuracy_comparison.png'

# %% [markdown]
# ## Explainability (Grad-CAM / Attention Rollout) — Primary Seed Only
#
# Generated once, from the models trained under `PRIMARY_SEED`, to avoid producing N complete sets of explainability figures. As before, these reuse the already-trained model objects directly (no reinitialization).

# %%
import cv2
from PIL import Image

class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.features = None
        self.target_layer.register_forward_hook(self.save_features)
        self.target_layer.register_full_backward_hook(self.save_gradients)

    def save_features(self, module, input, output):
        self.features = output.detach()

    def save_gradients(self, module, grad_input, grad_output):
        self.gradients = grad_output[0].detach()

    def generate_heatmap(self, input_tensor, class_idx=None):
        self.model.eval()
        output = self.model(input_tensor)
        if class_idx is None:
            class_idx = torch.argmax(output, dim=1).item()
        self.model.zero_grad()
        output[0, class_idx].backward()
        weights = torch.mean(self.gradients, dim=[2, 3])[0]
        cam = torch.zeros(self.features.shape[2:], dtype=torch.float32, device=self.features.device)
        for i, w in enumerate(weights):
            cam += w * self.features[0, i, :, :]
        cam = np.maximum(cam.cpu().numpy(), 0)
        if np.max(cam) != 0:
            cam = cam / np.max(cam)
        return cam, class_idx


def run_gradcam(model, target_layer, img_path, resolution, title, save_path, cmap_title_color='red'):
    cam_extractor = GradCAM(model, target_layer)
    raw_image = Image.open(img_path).convert('RGB')
    orig_w, orig_h = raw_image.size

    preprocess = transforms.Compose([
        transforms.Resize((resolution, resolution)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    input_tensor = preprocess(raw_image).unsqueeze(0).to(device)

    heatmap, predicted_class_idx = cam_extractor.generate_heatmap(input_tensor)
    heatmap_resized = cv2.resize(heatmap, (orig_w, orig_h))
    heatmap_color = cv2.applyColorMap(np.uint8(255 * heatmap_resized), cv2.COLORMAP_JET)
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)
    blended_img = cv2.addWeighted(np.array(raw_image), 0.6, heatmap_color, 0.4, 0)
    pred_label = CLASS_NAMES[predicted_class_idx]

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))
    axes[0].imshow(raw_image)
    axes[0].set_title("Input Tooth Scan/Patch", fontsize=12, fontweight='bold')
    axes[0].axis('off')
    axes[1].imshow(blended_img)
    axes[1].set_title(f"{title} (Pred: {pred_label})", fontsize=12, fontweight='bold', color=cmap_title_color)
    axes[1].axis('off')
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()
    print(f"Grad-CAM saved to '{save_path}'")


IMG_PATH = f'{DATA_DIR}/AdvanceEnamel_Caries/AdvanceEnamel_Caries_001.jpg'

run_gradcam(primary_models['ResNet-50'], primary_models['ResNet-50'].layer4[-1], IMG_PATH,
            resolution=384, title="ResNet-50 Grad-CAM", save_path='resnet_gradcam_multiseed.png')
# Out:
# Grad-CAM saved to 'resnet_gradcam_multiseed.png'

# %%
target_layer = list(primary_models['DenseNet-121'].features.denseblock4.children())[-1]
run_gradcam(primary_models['DenseNet-121'], target_layer, IMG_PATH, resolution=384,
            title="DenseNet-121 Grad-CAM", save_path='densenet_gradcam_multiseed.png', cmap_title_color='blue')
# Out:
# <sys>:0: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# Grad-CAM saved to 'densenet_gradcam_multiseed.png'

# %%
class ViTRollout:
    def __init__(self, model, discard_ratio=0.8, head_fusion="mean"):
        self.model = model
        self.discard_ratio = discard_ratio
        self.head_fusion = head_fusion
        self.attentions = []

    def rollout(self, input_tensor):
        self.model.eval()
        self.attentions = []

        n = input_tensor.shape[0]
        x = self.model._process_input(input_tensor)
        batch_class_token = self.model.class_token.expand(n, -1, -1)
        x = torch.cat([batch_class_token, x], dim=1)
        x = self.model.encoder.dropout(x)

        for layer in self.model.encoder.layers:
            x_norm = layer.ln_1(x)
            attn_output, attn_weights = layer.self_attention(x_norm, x_norm, x_norm, need_weights=True)
            self.attentions.append(attn_weights.detach())
            x = x + layer.dropout(attn_output)
            x_norm_mlp = layer.ln_2(x)
            x = x + layer.mlp(x_norm_mlp)

        with torch.no_grad():
            full_model_output = self.model(input_tensor)
            predicted_class_idx = torch.argmax(full_model_output, dim=1).item()

        attentions_stacked = torch.stack(self.attentions).squeeze(1)
        num_tokens = attentions_stacked.size(-1)
        result = torch.eye(num_tokens, device=input_tensor.device)

        for attention in attentions_stacked:
            if self.head_fusion == "mean":
                attention_heads_fused = torch.mean(attention, dim=0)
            elif self.head_fusion == "max":
                attention_heads_fused = torch.max(attention, dim=0).values

            flat = attention_heads_fused.view(-1)
            if flat.numel() > 0:
                topk_count = int(flat.numel() * self.discard_ratio)
                if 0 < topk_count < flat.numel():
                    _, indices = flat.topk(topk_count, -1, largest=False)
                    flat[indices] = 0

            I = torch.eye(num_tokens, device=input_tensor.device)
            a = (attention_heads_fused + I) / 2
            sum_val = a.sum(dim=-1, keepdim=True)
            a = a / (sum_val + 1e-6)
            result = torch.matmul(a, result)

        mask = result[0, 1:]
        grid_size = int(np.sqrt(mask.size(0)))
        mask = mask.reshape(grid_size, grid_size).cpu().numpy()
        if np.max(mask) != 0:
            mask = mask / np.max(mask)
        return mask, predicted_class_idx


rollout_engine = ViTRollout(primary_models['ViT-B/16'], discard_ratio=0.8, head_fusion="mean")

raw_image = Image.open(IMG_PATH).convert('RGB')
orig_w, orig_h = raw_image.size
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
input_tensor = preprocess(raw_image).unsqueeze(0).to(device)

attention_mask, predicted_class_idx = rollout_engine.rollout(input_tensor)
attention_resized = cv2.resize(attention_mask, (orig_w, orig_h), interpolation=cv2.INTER_CUBIC)
attention_color = cv2.applyColorMap(np.uint8(255 * attention_resized), cv2.COLORMAP_JET)
attention_color = cv2.cvtColor(attention_color, cv2.COLOR_BGR2RGB)
blended_img = cv2.addWeighted(np.array(raw_image), 0.6, attention_color, 0.4, 0)
pred_label = CLASS_NAMES[predicted_class_idx]

fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(raw_image)
axes[0].set_title("Input Tooth Scan/Patch", fontsize=12, fontweight='bold')
axes[0].axis('off')
axes[1].imshow(blended_img)
axes[1].set_title(f"ViT-B/16 Attention Rollout (Pred: {pred_label})", fontsize=12, fontweight='bold', color='purple')
axes[1].axis('off')
plt.tight_layout()
plt.savefig('vit_attention_rollout_multiseed.png', dpi=300)
plt.show()
print("Saved to 'vit_attention_rollout_multiseed.png'")
# Out:
# Saved to 'vit_attention_rollout_multiseed.png'

# %%
import copy

def set_relu_inplace_false(model):
    for module in model.modules():
        if isinstance(module, torch.nn.ReLU):
            module.inplace = False
    return model

# Create a deep copy of the SqueezeNet model and modify its ReLU layers
squeezenet_gradcam_model = copy.deepcopy(primary_models['SqueezeNet 1.1'])
squeezenet_gradcam_model = set_relu_inplace_false(squeezenet_gradcam_model)

target_layer = squeezenet_gradcam_model.classifier[1]
run_gradcam(squeezenet_gradcam_model, target_layer, IMG_PATH, resolution=224,
            title="SqueezeNet 1.1 Grad-CAM", save_path='squeezenet_gradcam_multiseed.png', cmap_title_color='green')
# Out:
# Grad-CAM saved to 'squeezenet_gradcam_multiseed.png'

# %% [markdown]
# ## Notes for the paper
#
# - Report **Table 1 as mean ± std** (cell 8's `display_df`), not single-run point estimates.
# - Report the **pairwise p-values** (cell 9) alongside the accuracy table, and explicitly state
#   which pairs of models are/aren't statistically distinguishable at p<0.05 with this seed count.
# - If `SEEDS` was trimmed below 5 for runtime reasons, say so explicitly in Methods (N seeds is
#   small enough that it materially affects statistical power).
# - The explainability figures remain single-image qualitative illustrations (now from the
#   primary seed only) — quantitative interpretability evaluation is still open future work.
